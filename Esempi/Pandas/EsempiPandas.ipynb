# %%
import pandas as pd
#import numpy as np

# %%
d = {
    "c1": [1,2,3,4,5,6],
    "c2": [2,4,6,8,10,12],
    "c3": [3,6,9,12,15,18],
    "c4": [4,8,12,16,20,24]
}

df = pd.DataFrame(d)
df
# Out:
#    c1  c2  c3  c4
# 0   1   2   3   4
# 1   2   4   6   8
# 2   3   6   9  12
# 3   4   8  12  16
# 4   5  10  15  20
# 5   6  12  18  24

# %%
url = "https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv"
df = pd.read_csv(url)
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
df.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 13 columns]

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 790  714               Noibat   Flying  ...    55           6      False
# 791  715              Noivern   Flying  ...   123           6      False
# 792  716              Xerneas    Fairy  ...    99           6       True
# 793  717              Yveltal     Dark  ...    99           6       True
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [10 rows x 13 columns]

# %%
df[["Name", "Type 1", "Type 2"]].head(20)
# Out:
#                          Name Type 1  Type 2
# 0                   Bulbasaur  Grass  Poison
# 1                     Ivysaur  Grass  Poison
# 2                    Venusaur  Grass  Poison
# 3       VenusaurMega Venusaur  Grass  Poison
# 4                  Charmander   Fire     NaN
# 5                  Charmeleon   Fire     NaN
# 6                   Charizard   Fire  Flying
# 7   CharizardMega Charizard X   Fire  Dragon
# 8   CharizardMega Charizard Y   Fire  Flying
# 9                    Squirtle  Water     NaN
# 10                  Wartortle  Water     NaN
# 11                  Blastoise  Water     NaN
# 12    BlastoiseMega Blastoise  Water     NaN
# 13                   Caterpie    Bug     NaN
# 14                    Metapod    Bug     NaN
# 15                 Butterfree    Bug  Flying
# 16                     Weedle    Bug  Poison
# 17                     Kakuna    Bug  Poison
# 18                   Beedrill    Bug  Poison
# 19      BeedrillMega Beedrill    Bug  Poison

# %%
df.iloc[:,[1,2,4]]
# Out:
#                       Name   Type 1  Total
# 0                Bulbasaur    Grass    318
# 1                  Ivysaur    Grass    405
# 2                 Venusaur    Grass    525
# 3    VenusaurMega Venusaur    Grass    625
# 4               Charmander     Fire    309
# ..                     ...      ...    ...
# 795                Diancie     Rock    600
# 796    DiancieMega Diancie     Rock    700
# 797    HoopaHoopa Confined  Psychic    600
# 798     HoopaHoopa Unbound  Psychic    680
# 799              Volcanion     Fire    600
#
# [800 rows x 3 columns]

# %%
df.iloc[10:21]
# Out:
#      #                     Name  Type 1  ... Speed  Generation  Legendary
# 10   8                Wartortle   Water  ...    58           1      False
# 11   9                Blastoise   Water  ...    78           1      False
# 12   9  BlastoiseMega Blastoise   Water  ...    78           1      False
# 13  10                 Caterpie     Bug  ...    45           1      False
# 14  11                  Metapod     Bug  ...    30           1      False
# 15  12               Butterfree     Bug  ...    70           1      False
# 16  13                   Weedle     Bug  ...    50           1      False
# 17  14                   Kakuna     Bug  ...    35           1      False
# 18  15                 Beedrill     Bug  ...    75           1      False
# 19  15    BeedrillMega Beedrill     Bug  ...   145           1      False
# 20  16                   Pidgey  Normal  ...    56           1      False
#
# [11 rows x 13 columns]

# %%
df.loc[df["Name"] == "Weavile"]
# Out:
#        #     Name Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 512  461  Weavile   Dark    Ice  ...       85    125           4      False
#
# [1 rows x 13 columns]

# %%
df.loc[df["Type 1"] == "Dark"]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 212  197                Umbreon   Dark  ...    65           2      False
# 213  198                Murkrow   Dark  ...    91           2      False
# 233  215                Sneasel   Dark  ...   115           2      False
# 246  228               Houndour   Dark  ...    65           2      False
# 247  229               Houndoom   Dark  ...    95           2      False
# 248  229  HoundoomMega Houndoom   Dark  ...   115           2      False
# 284  261              Poochyena   Dark  ...    35           3      False
# 285  262              Mightyena   Dark  ...    70           3      False
# 326  302                Sableye   Dark  ...    50           3      False
# 327  302    SableyeMega Sableye   Dark  ...    20           3      False
# 392  359                  Absol   Dark  ...    75           3      False
# 393  359        AbsolMega Absol   Dark  ...   115           3      False
# ...

# %%
df.loc[(df["Type 1"] == "Fire") & (df["Legendary"] == True)]
# Out:
#        #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 158  146    Moltres   Fire  Flying  ...       85     90           1       True
# 263  244      Entei   Fire     NaN  ...       75    100           2       True
# 270  250      Ho-oh   Fire  Flying  ...      154     90           2       True
# 542  485    Heatran   Fire   Steel  ...      106     77           4       True
# 799  721  Volcanion   Fire   Water  ...       90     70           6       True
#
# [5 rows x 13 columns]

# %%
df.loc[15:21, ["Type 1", "Speed"]]
# Out:
#     Type 1  Speed
# 15     Bug     70
# 16     Bug     50
# 17     Bug     35
# 18     Bug     75
# 19     Bug    145
# 20  Normal     56
# 21  Normal     71

# %%
df.sort_values("Name", ascending=False)
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 794  718         Zygarde50% Forme   Dragon  ...    95           6       True
# 695  634                 Zweilous     Dark  ...    58           5      False
# 46    41                    Zubat   Poison  ...    55           1      False
# 631  570                    Zorua     Dark  ...    65           5      False
# 632  571                  Zoroark     Dark  ...   105           5      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 393  359          AbsolMega Absol     Dark  ...   115           3      False
# 392  359                    Absol     Dark  ...    75           3      False
# 68    63                     Abra  Psychic  ...    90           1      False
# 511  460  AbomasnowMega Abomasnow    Grass  ...    30           4      False
# 510  460                Abomasnow    Grass  ...    60           4      False
#
# [800 rows x 13 columns]

# %%
df.sort_values(["Type 1", "Type 2"], ascending=True)
# Out:
#        #                     Name Type 1  ... Speed  Generation  Legendary
# 656  595                   Joltik    Bug  ...    65           5      False
# 657  596               Galvantula    Bug  ...   108           5      False
# 231  214                Heracross    Bug  ...    85           2      False
# 232  214  HeracrossMega Heracross    Bug  ...    75           2      False
# 697  636                 Larvesta    Bug  ...    60           5      False
# ..   ...                      ...    ...  ...   ...         ...        ...
# 655  594                Alomomola  Water  ...    65           5      False
# 724  656                  Froakie  Water  ...    71           6      False
# 725  657                Frogadier  Water  ...    97           6      False
# 762  692                Clauncher  Water  ...    44           6      False
# 763  693                Clawitzer  Water  ...    59           6      False
#
# [800 rows x 13 columns]

# %%
df["Differenza Atk-Def"] = df["Attack"] - df["Defense"]
df["Differenza Sp. Atk-Sp. Def"] = df["Sp. Atk"] - df["Sp. Def"]
df
# Out:
#        #                   Name  ... Differenza Atk-Def Differenza Sp. Atk-Sp. Def
# 0      1              Bulbasaur  ...                  0                          0
# 1      2                Ivysaur  ...                 -1                          0
# 2      3               Venusaur  ...                 -1                          0
# 3      3  VenusaurMega Venusaur  ...                -23                          2
# 4      4             Charmander  ...                  9                         10
# ..   ...                    ...  ...                ...                        ...
# 795  719                Diancie  ...                -50                        -50
# 796  719    DiancieMega Diancie  ...                 50                         50
# 797  720    HoopaHoopa Confined  ...                 50                         20
# 798  720     HoopaHoopa Unbound  ...                100                         40
# ...

# %%
df = df.drop(columns=[""])
df

# %%
df.iloc[80:110,[1,6]]
# Out:
#                     Name  Attack
# 80               Geodude      80
# 81              Graveler      95
# 82                 Golem     120
# 83                Ponyta      85
# 84              Rapidash     100
# 85              Slowpoke      65
# 86               Slowbro      75
# 87   SlowbroMega Slowbro      75
# 88             Magnemite      35
# 89              Magneton      60
# 90            Farfetch'd      65
# 91                 Doduo      85
# 92                Dodrio     110
# 93                  Seel      45
# 94               Dewgong      70
# 95                Grimer      80
# 96                   Muk     105
# 97              Shellder      65
# 98              Cloyster      95
# 99                Gastly      35
# 100              Haunter      50
# 101               Gengar      65
# 102    GengarMega Gengar      65
# 103                 Onix      45
# 104              Drowzee      48
# 105                Hypno      73
# 106               Krabby     105
# ...

# %%
df.loc[80:110,"#" : "Type 2"]
# Out:
#        #                 Name    Type 1   Type 2
# 80    74              Geodude      Rock   Ground
# 81    75             Graveler      Rock   Ground
# 82    76                Golem      Rock   Ground
# 83    77               Ponyta      Fire      NaN
# 84    78             Rapidash      Fire      NaN
# 85    79             Slowpoke     Water  Psychic
# 86    80              Slowbro     Water  Psychic
# 87    80  SlowbroMega Slowbro     Water  Psychic
# 88    81            Magnemite  Electric    Steel
# 89    82             Magneton  Electric    Steel
# 90    83           Farfetch'd    Normal   Flying
# 91    84                Doduo    Normal   Flying
# 92    85               Dodrio    Normal   Flying
# 93    86                 Seel     Water      NaN
# 94    87              Dewgong     Water      Ice
# 95    88               Grimer    Poison      NaN
# 96    89                  Muk    Poison      NaN
# 97    90             Shellder     Water      NaN
# ...

# %%
df.groupby("Name")

# %%
df.groupby(["Name", "Type 1"]).first()
# Out:
#                                    #  ... Differenza Sp. Atk-Sp. Def
# Name                    Type 1        ...
# Abomasnow               Grass    460  ...                          7
# AbomasnowMega Abomasnow Grass    460  ...                         27
# Abra                    Psychic   63  ...                         50
# Absol                   Dark     359  ...                         15
# AbsolMega Absol         Dark     359  ...                         55
# ...                              ...  ...                        ...
# Zoroark                 Dark     571  ...                         60
# Zorua                   Dark     570  ...                         40
# Zubat                   Poison    41  ...                        -10
# Zweilous                Dark     634  ...                         -5
# Zygarde50% Forme        Dragon   718  ...                        -14
#
# [800 rows x 13 columns]

# %%
df.groupby("Name").groups.keys()
# Out:
# dict_keys(['Abomasnow', 'AbomasnowMega Abomasnow', 'Abra', 'Absol', 'AbsolMega Absol', 'Accelgor', 'AegislashBlade Forme', 'AegislashShield Forme', 'Aerodactyl', 'AerodactylMega Aerodactyl', 'Aggron', 'AggronMega Aggron', 'Aipom', 'Alakazam', 'AlakazamMega Alakazam', 'Alomomola', 'Altaria', 'AltariaMega Altaria', 'Amaura', 'Ambipom', 'Amoonguss', 'Ampharos', 'AmpharosMega Ampharos', 'Anorith', 'Arbok', 'Arcanine', 'Arceus', 'Archen', 'Archeops', 'Ariados', 'Armaldo', 'Aromatisse', 'Aron', 'Articuno', 'Audino', 'AudinoMega Audino', 'Aurorus', 'Avalugg', 'Axew', 'Azelf', 'Azumarill', 'Azurill', 'Bagon', 'Baltoy', 'Banette', 'BanetteMega Banette', 'Barbaracle', 'Barboach', 'Basculin', 'Bastiodon', 'Bayleef', 'Beartic', 'Beautifly', 'Beedrill', 'BeedrillMega Beedrill', 'Beheeyem', 'Beldum', 'Bellossom', 'Bellsprout', 'Bergmite', 'Bibarel', 'Bidoof', 'Binacle', 'Bisharp', 'Blastoise', 'BlastoiseMega Blastoise', 'Blaziken', 'BlazikenMega Blaziken', 'Blissey', 'Blitzle', 'Boldore', 'Bonsly'
# ...

# %%
#%time
df.to_excel("./file.xlsx")
df.to_csv("./file.csv")
df.to_json("./file.json")
